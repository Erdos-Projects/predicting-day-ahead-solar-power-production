# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
power_2105 = pd.read_csv('data_ds_project/systems/prize/2105/2105_meter_data.csv')
