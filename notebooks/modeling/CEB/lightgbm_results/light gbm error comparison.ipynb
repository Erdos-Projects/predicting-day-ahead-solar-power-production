# %% [markdown]
# Light GBM error comparison

# %%
import pandas as pd

df10 = pd.read_csv('10_None.csv')
df50 = pd.read_csv('50_None.csv')
df51 = pd.read_csv('51_None.csv')

# %% [markdown]
# System 10

# %%
df = df10

summary = pd.DataFrame({
    "mean": df.mean(axis=0),
    "median": df.median(axis=0),
    "max": df.max(axis=0),
    "std": df.std(axis=0)
})

summary = summary.reset_index()
summary = summary.rename(columns={"index": "hyperparameters"})

# sort by mean
summary = summary.sort_values("mean")

display(summary.head(1))
#48
#but 56 isn't too bad

df = df50

summary = pd.DataFrame({
    "mean": df.mean(axis=0),
    "median": df.median(axis=0),
    "max": df.max(axis=0),
    "std": df.std(axis=0)
})

summary = summary.reset_index()
summary = summary.rename(columns={"index": "hyperparameters"})

# sort by mean
summary = summary.sort_values("mean")

display(summary.head(1))
#48
#but 56 isn't that bad
df = df51

summary = pd.DataFrame({
    "mean": df.mean(axis=0),
    "median": df.median(axis=0),
    "max": df.max(axis=0),
    "std": df.std(axis=0)
})

summary = summary.reset_index()
summary = summary.rename(columns={"index": "hyperparameters"})

# sort by mean
summary = summary.sort_values("mean")

summary.head(25)
#56: (31, 5, 0.1, 100, 0.8, 0.8)
summary.loc[summary['hyperparameters']=='(31, 5, 0.1, 100, 0.8, 0.8)']
# Out:
#                  hyperparameters      mean    median       max       std
# 48  (31, -1, 0.1, 100, 0.8, 0.8)  0.039082  0.025635  0.260873  0.038583
#                  hyperparameters      mean    median       max       std
# 48  (31, -1, 0.1, 100, 0.8, 0.8)  1.019386  0.700245  8.926571  1.129322
#                 hyperparameters      mean    median       max       std
# 56  (31, 5, 0.1, 100, 0.8, 0.8)  1.099389  0.784742  5.550183  1.028978

# %% [markdown]
# System 50

# %%
df = df50

summary = pd.DataFrame({
    "mean": df.mean(axis=0),
    "median": df.median(axis=0),
    "max": df.max(axis=0),
    "std": df.std(axis=0)
})

summary = summary.reset_index()
summary = summary.rename(columns={"index": "hyperparameters"})

# sort by mean
summary = summary.sort_values("mean")

summary.head(25)

#48
#but 56 isn't that bad
# Out:
#                  hyperparameters      mean    median        max       std
# 48  (31, -1, 0.1, 100, 0.8, 0.8)  1.019386  0.700245   8.926571  1.129322
# 50  (31, -1, 0.1, 100, 1.0, 0.8)  1.019386  0.700245   8.926571  1.129322
# 56   (31, 5, 0.1, 100, 0.8, 0.8)  1.024605  0.656397   9.220692  1.124431
# 58   (31, 5, 0.1, 100, 1.0, 0.8)  1.024804  0.656397   9.220692  1.124655
# 68   (31, 7, 0.2, 100, 0.8, 0.8)  1.030222  0.667478   9.249678  1.166259
# 70   (31, 7, 0.2, 100, 1.0, 0.8)  1.030222  0.667478   9.249678  1.166259
# 24  (15, -1, 0.1, 100, 0.8, 0.8)  1.036749  0.670985   8.005422  1.128024
# 26  (15, -1, 0.1, 100, 1.0, 0.8)  1.036749  0.670985   8.005422  1.128024
# 65   (31, 7, 0.1, 100, 0.8, 1.0)  1.042202  0.654376  10.233054  1.263264
# 67   (31, 7, 0.1, 100, 1.0, 1.0)  1.042202  0.654376  10.233054  1.263264
# 4    (7, -1, 0.2, 100, 0.8, 0.8)  1.043333  0.680020  10.458571  1.144688
# 6    (7, -1, 0.2, 100, 1.0, 0.8)  1.043333  0.680020  10.458571  1.144688
# ...

# %% [markdown]
# System 51

# %%
df = df51

summary = pd.DataFrame({
    "mean": df.mean(axis=0),
    "median": df.median(axis=0),
    "max": df.max(axis=0),
    "std": df.std(axis=0)
})

summary = summary.reset_index()
summary = summary.rename(columns={"index": "hyperparameters"})

# sort by mean
summary = summary.sort_values("mean")

summary.head(25)
#56: (31, 5, 0.1, 100, 0.8, 0.8)
summary.loc[summary['hyperparameters']=='(31, 5, 0.1, 100, 0.8, 0.8)']
# Out:
#                 hyperparameters      mean    median       max       std
# 56  (31, 5, 0.1, 100, 0.8, 0.8)  1.099389  0.784742  5.550183  1.028978
