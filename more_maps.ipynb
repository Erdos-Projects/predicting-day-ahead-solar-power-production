# %%
import pandas as pd
from pathlib import Path
import pyarrow as pa  # not yet needed, might need it later
import pyarrow.parquet as pq
import pyarrow.compute as pc  # not yet needed, might need it later.
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Import the metadata container

# %%
systems_cleaned = pd.read_csv('./data/core/systems_cleaned.csv')

# %%
systems_cleaned.columns
# Out:
# Index(['system_id', 'system_public_name', 'site_location',
#        'timezone_or_utc_offset', 'latitude', 'longitude', 'elevation_m',
#        'dc_capacity_kW', 'kg_climate', 'pvcz_composite', 'pvcz_t_rack',
#        'pvcz_t_roof', 'pvcz_humidity', 'pvcz_wind', 'tracking', 'type',
#        'azimuth', 'tilt', 'first_timestamp', 'last_timestamp', 'years',
#        'number_records', 'dataset_size_mb', 'available_sensor_channels',
#        'qa_status', 'qa_issue', 'first_year', 'is_prize_data',
#        'is_lake_parquet_data', 'is_lake_csv_data', 'has_irrad_data',
#        'has_power_data', 'has_ambient_temp_data', 'has_some_temp_data',
#        'has_ac_data', 'has_dc_data', 'has_voltage_data', 'has_current_data'],
#       dtype='str')

# %% [markdown]
# # First Group -- just locations of all sites, by Type

# %%
system_locs = systems_cleaned[[
    'system_id', 'latitude', 'longitude', 'is_prize_data',
    'is_lake_parquet_data', 'is_lake_csv_data'
]].drop_duplicates()

# %%
system_locs = system_locs[
    system_locs['is_prize_data']
    | system_locs['is_lake_parquet_data']
    | system_locs['is_lake_csv_data']
]

# %%
def locs_type(row):
    if row['is_prize_data']:
        return 'prize'
    elif row['is_lake_parquet_data']:
        return 'parquet'
    elif row['is_lake_csv_data']:
        return 'csv'
    else:
        return 'No data'

# %%
system_locs['system_type'] = system_locs.apply(locs_type, axis=1)

# %% [markdown]
# Following example from https://plotly.com/python/scatter-plots-on-maps/

# %%
fig = px.scatter_geo(
    data_frame = system_locs,
    lat = 'latitude',
    lon = 'longitude',
    color='system_type'
)

fig.update_layout(
        title = 'Locations of PVDAQ data sites',
        # comment or un-comment to get global vs. USA
        # geo_scope='usa',
    )
fig.show()

# %% [markdown]
# (We defer exploration of the non-US site to the postscript below.)

# %% [markdown]
# Let's do the non-CSV sites.

# %%
system_locs_not_csv = system_locs[
    system_locs['is_prize_data']
    | system_locs['is_lake_parquet_data']
]

# %%
fig = px.scatter_geo(
    data_frame = system_locs_not_csv,
    lat = 'latitude',
    lon = 'longitude',
    color='system_type'
)

fig.update_layout(
        title = 'Locations of PVDAQ data sites',
        geo_scope='usa',
    )
fig.show()

# %% [markdown]
# ## Group 2: Let's take all sites with at least 4 features and talk about their characteristics.

# %%
def has_four_features(row):
    running_total = 0
    for col in ['has_some_temp_data', 'has_current_data', 
                'has_voltage_data', 'has_power_data', 'has_irrad_data']:
        running_total += int(row[col])
    return running_total >= 4  # a boolean


systems_cleaned['four_features'] = systems_cleaned.apply(has_four_features, axis=1)
systems_enough_features = systems_cleaned[systems_cleaned['four_features']]

# %%
systems_enough_features.shape
# Out:
# (57, 39)

# %%
fig = px.scatter_geo(
    data_frame = systems_enough_features,
    lat = 'latitude',
    lon = 'longitude',
    color='first_year'
)

fig.update_layout(
        title = 'Rankings of Rich-Data Sites by Starting Year',
        geo_scope='usa',
    )
fig.show()

# %%
fig = px.scatter_geo(
    data_frame = systems_enough_features,
    lat = 'latitude',
    lon = 'longitude',
    color = 'years'
)

fig.update_layout(
        title = 'Time Durations of Data for High-Quality Facilities',
        geo_scope='usa',
    )
fig.show()

# %% [markdown]
# Hard to read, so let's make a histogram.

# %%
sns.histplot(
    data = systems_enough_features,
    x = 'years',
)
plt.title('Terms of Data Collected for High-Quality Installations.')
plt.show()

# %% [markdown]
# The metadata also lists dc_capacity_kW

# %%
fig = px.scatter_geo(
    data_frame = systems_enough_features,
    lat = 'latitude',
    lon = 'longitude',
    color = 'dc_capacity_kW',
)

fig.update_layout(
        title = 'Power Outputs for High-Quality Facilities',
        geo_scope='usa',
    )
fig.show()

# %%
sns.histplot(
    data = systems_enough_features,
    x = 'dc_capacity_kW',
)
plt.title('DC Power Capacity for High-Quality Installations.')
plt.show()

# %%
fig = px.scatter_geo(
    data_frame = systems_enough_features,
    lat = 'latitude',
    lon = 'longitude',
    color = 'kg_climate',
)

fig.update_layout(
        title = 'Köppen–Geiger climate classification for High-Quality Facilities',
        geo_scope='usa',
    )
fig.show()

# %% [markdown]
# # Postscript: What about that non-USA site?

# %%
system_non_us = system_locs[
    system_locs['longitude'] > -40
]

# %%
system_non_us.head()
# Out:
#      system_id  latitude  longitude  is_prize_data  is_lake_parquet_data  \
# 143       1416   35.7793   78.63411          False                  True
#
#      is_lake_csv_data system_type
# 143              True     parquet

# %%
metrics_dir = Path('./data/raw/parquet-metrics/')
# Note: We generally give a directory, rather than an individual file, to the next step.
metrics_pq = pq.ParquetDataset(metrics_dir)
metrics_df = metrics_pq.read().to_pandas()

# %%
metrics_df[
    metrics_df['sensor_name'].str.contains('humid')
]
# Out:
#       system_id  metric_id        sensor_name common_name raw_units units  \
# 163        1203       2892  relative_humidity    Humidity         %     %
# 303        1229        883  relative_humidity    Humidity         -     -
# 310        1230        892  relative_humidity    Humidity         -     -
# 320        1239       3017  relative_humidity    Humidity         %     %
# 455        1276       3027  relative_humidity    Humidity         %     %
# 470        1277       3042  relative_humidity    Humidity         %     %
# 493        1278       3057  relative_humidity    Humidity         %     %
# 1329         34       2687  relative_humidity    Humidity         %     %
# 1344         35       2705  relative_humidity    Humidity         %     %
#
#       calc_scale  calc_offset calc_details aggregation_type source_type  \
# 163          1.0          0.0                           avg         NaN
# 303          1.0          0.0                           avg         NaN
# 310          1.0          0.0                           NaN         NaN
# 320          1.0          0.0                           avg         NaN
# 455          1.0          0.0                           avg         NaN
# 470          1.0          0.0                           avg         NaN
# 493          1.0          0.0                           avg         NaN
# 1329         1.0          0.0                           avg         NaN
# 1344         1.0          0.0                           avg         NaN
#
#       source_id comments            standard_name
# 163         NaN           relative_humidity__2892
# 303         NaN            relative_humidity__883
# 310         NaN            relative_humidity__892
# 320         NaN           relative_humidity__3017
# 455         NaN           relative_humidity__3027
# 470         NaN           relative_humidity__3042
# 493         NaN           relative_humidity__3057
# 1329        NaN           relative_humidity__2687
# 1344        NaN           relative_humidity__2705

# %%
intl_site = metrics_df[metrics_df['system_id'] == 1416]

# %%
intl_site
# Out:
#       system_id  metric_id          sensor_name            common_name  \
# 1107       1416       4742             dc_power               DC power
# 1108       1416       4762       ac_current_phA             AC current
# 1109       1416       4763       ac_current_phB             AC current
# 1110       1416       4764       ac_current_phC             AC current
# 1111       1416       4749           ac_current             AC current
# 1112       1416       4746         power_factor               AC other
# 1113       1416       4753     power_factor_phA               AC other
# 1114       1416       4754     power_factor_phB               AC other
# 1115       1416       4755     power_factor_phC               AC other
# 1116       1416       4745   apparent_power_kVA               AC other
# 1117       1416       4744  reactive_power_kVAR               AC other
# 1118       1416       4747      ac_voltage_LtoL             AC voltage
# 1119       1416       4748      ac_voltage_LtoN             AC voltage
# 1120       1416       4756        ac_voltage_AB             AC voltage
# 1121       1416       4757        ac_voltage_BC             AC voltage
# 1122       1416       4758        ac_voltage_AC             AC voltage
# 1123       1416       4759        ac_voltage_AN             AC voltage
# 1124       1416       4760        ac_voltage_BN             AC voltage
# 1125       1416       4761        ac_voltage_CN             AC voltage
# 1126       1416       4737  dc_current_positive             DC current
# 1127       1416       4740  dc_current_negative             DC current
# 1128       1416       4733  das_battery_voltage     DC voltage battery
# 1129       1416       4741    dc_power_negative               DC power
# 1130       1416       4738    dc_power_positive               DC power
# 1131       1416       4736  dc_voltage_positive             DC voltage
# 1132       1416       4739  dc_voltage_negative             DC voltage
# 1133       1416       4734             das_temp      Temperature panel
# 1134       1416       4735       enclosure_temp  Temperature enclosure
# 1135       1416       4743        real_power_kW         AC power other
# 1136       1416       4750    real_power_phA_kW         AC power other
# 1137       1416       4751    real_power_phB_kW         AC power other
# 1138       1416       4752    real_power_phC_kW         AC power other
#
#      raw_units units  calc_scale  calc_offset calc_details aggregation_type  \
# 1107         W     W         1.0          0.0                           avg
# 1108         A     A         1.0          0.0                           avg
# 1109         A     A         1.0          0.0                           avg
# 1110         A     A         1.0          0.0                           avg
# 1111         A     A         1.0          0.0                           avg
# 1112         -     -         1.0          0.0                           avg
# 1113         -     -         1.0          0.0                           avg
# 1114         -     -         1.0          0.0                           avg
# 1115         -     -         1.0          0.0                           avg
# 1116       kVA    VA      1000.0          0.0                           avg
# 1117      kVAR   VAR      1000.0          0.0                           avg
# 1118         V     V         1.0          0.0                           avg
# 1119         V     V         1.0          0.0                           avg
# 1120         V     V         1.0          0.0                           avg
# 1121         V     V         1.0          0.0                           avg
# 1122         V     V         1.0          0.0                           avg
# 1123         V     V         1.0          0.0                           avg
# 1124         V     V         1.0          0.0                           avg
# 1125         V     V         1.0          0.0                           avg
# 1126         A     A         1.0          0.0                           avg
# 1127         A     A         1.0          0.0                           avg
# 1128         V     V         1.0          0.0                           avg
# 1129         W     W         1.0          0.0                           avg
# 1130         W     W         1.0          0.0                           avg
# 1131         V     V         1.0          0.0                           avg
# 1132         V     V         1.0          0.0                           avg
# 1133         C     C         1.0          0.0                           avg
# 1134         C     C         1.0          0.0                           avg
# 1135        kW     W      1000.0          0.0                           avg
# 1136        kW     W      1000.0          0.0                           avg
# 1137        kW     W      1000.0          0.0                           avg
# 1138        kW     W      1000.0          0.0                           avg
#
#      source_type  source_id comments              standard_name
# 1107         NaN        NaN                      dc_power__4742
# 1108         NaN        NaN                ac_current_pha__4762
# 1109         NaN        NaN                ac_current_phb__4763
# 1110         NaN        NaN                ac_current_phc__4764
# 1111         NaN        NaN                    ac_current__4749
# 1112         NaN        NaN                  power_factor__4746
# 1113         NaN        NaN              power_factor_pha__4753
# 1114         NaN        NaN              power_factor_phb__4754
# 1115         NaN        NaN              power_factor_phc__4755
# 1116         NaN        NaN            apparent_power_kva__4745
# 1117         NaN        NaN           reactive_power_kvar__4744
# 1118         NaN        NaN               ac_voltage_ltol__4747
# 1119         NaN        NaN               ac_voltage_lton__4748
# 1120         NaN        NaN                 ac_voltage_ab__4756
# 1121         NaN        NaN                 ac_voltage_bc__4757
# 1122         NaN        NaN                 ac_voltage_ac__4758
# 1123         NaN        NaN                 ac_voltage_an__4759
# 1124         NaN        NaN                 ac_voltage_bn__4760
# 1125         NaN        NaN                 ac_voltage_cn__4761
# 1126         NaN        NaN           dc_current_positive__4737
# 1127         NaN        NaN           dc_current_negative__4740
# 1128         NaN        NaN           das_battery_voltage__4733
# 1129         NaN        NaN             dc_power_negative__4741
# 1130         NaN        NaN             dc_power_positive__4738
# 1131         NaN        NaN           dc_voltage_positive__4736
# 1132         NaN        NaN           dc_voltage_negative__4739
# 1133         NaN        NaN                      das_temp__4734
# 1134         NaN        NaN                enclosure_temp__4735
# 1135         NaN        NaN                 real_power_kw__4743
# 1136         NaN        NaN             real_power_pha_kw__4750
# 1137         NaN        NaN             real_power_phb_kw__4751
# 1138         NaN        NaN             real_power_phc_kw__4752

# %%
data_asia_dir = Path('../data_ds_project/systems/parquet/1416/')
data_asia_pq = pq.ParquetDataset(data_asia_dir,
                                 filters=[
                                     ('metric_id', 'in', [4734, 4735, 4744, 4745])
                                 ])
data_asia_df = data_asia_pq.read().to_pandas()

# %%
data_asia_df.loc[30000:30019, 'measured_on']
# Out:
# 30000   2015-11-06 02:15:55
# 30001   2015-11-06 02:16:00
# 30002   2015-11-06 02:16:05
# 30003   2015-11-06 02:16:10
# 30004   2015-11-06 02:16:15
# 30005   2015-11-06 02:16:20
# 30006   2015-11-06 02:16:25
# 30007   2015-11-06 02:16:30
# 30008   2015-11-06 02:16:35
# 30009   2015-11-06 02:16:40
# 30010   2015-11-06 02:16:45
# 30011   2015-11-06 02:16:50
# 30012   2015-11-06 02:16:55
# 30013   2015-11-06 02:17:00
# 30014   2015-11-06 02:17:05
# 30015   2015-11-06 02:17:10
# 30016   2015-11-06 02:17:15
# 30017   2015-11-06 02:17:20
# 30018   2015-11-06 02:17:25
# 30019   2015-11-06 02:17:30
# Name: measured_on, dtype: datetime64[ns]

# %%
data_asia_df['measured_on'] = pd.to_datetime(
    data_asia_df['measured_on'], format = "%Y-%m-%d %H:%M:%S"
).astype('datetime64[s]')

# %%
data_asia_df['measured_on'].max()
# Out:
# Timestamp('2018-03-26 22:50:35')
